# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns # visualization tool

# %%
# read in csv my data file and display first 5 rows of dataset as data frame

df_mutual=pd.read_csv('data/MutualFunds.csv')
df_mutual.head()
# Out:
#   fund_symbol  quote_type region                  fund_short_name  \
# 0       AAAAX  MutualFund     US  DWS RREEF Real Assets Fund - Cl
# 1       AAAEX  MutualFund     US  AllianzGI Health Sciences Fund
# 2       AAAFX  MutualFund     US                              NaN
# 3       AAAGX  MutualFund     US  Thrivent Large Cap Growth Fund
# 4       AAAHX  MutualFund     US                              NaN
#
#                                       fund_long_name currency  \
# 0               DWS RREEF Real Assets Fund - Class A      USD
# 1      Virtus AllianzGI Health Sciences Fund Class P      USD
# 2  American Century One Choice Blend+ 2015 Portfo...      USD
# 3             Thrivent Large Cap Growth Fund Class A      USD
# 4  American Century One Choice Blend+ 2015 Portfo...      USD
#
#    initial_investment  subsequent_investment     fund_category  \
# 0              1000.0                   50.0  World Allocation
# 1           1000000.0                    NaN            Health
# ...

# %%
df_mutual.shape
# Out:
# (23783, 298)

# %%
# check data types of columns
df_mutual.dtypes
# Out:
# fund_symbol             object
# quote_type              object
# region                  object
# fund_short_name         object
# fund_long_name          object
#                         ...
# peer_social_max        float64
# governance_score       float64
# peer_governance_min    float64
# peer_governance_avg    float64
# peer_governance_max    float64
# Length: 298, dtype: object

# %%
# how can i see all the columns and rows 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# check for missing values
df_mutual.isnull().sum()
# Out:
# fund_symbol                                     0
# quote_type                                      0
# region                                          0
# fund_short_name                               824
# fund_long_name                                  5
# currency                                        0
# initial_investment                           7298
# subsequent_investment                       14840
# fund_category                                 663
# fund_family                                     0
# exchange_code                                   0
# exchange_name                                   0
# exchange_timezone                               0
# management_name                                 0
# management_bio                                479
# management_start_date                           0
# total_net_assets                               34
# year_to_date_return                           401
# day50_moving_average                            1
# ...

# %%
# check for number of unique values in each column
df_mutual.nunique()
# Out:
# fund_symbol                                 23783
# fund_short_name                              3044
# fund_long_name                               6644
# initial_investment                             48
# subsequent_investment                          20
# fund_category                                 119
# fund_family                                   310
# management_name                              1388
# management_bio                               1300
# management_start_date                        2316
# total_net_assets                             7173
# year_to_date_return                          3956
# day50_moving_average                        15870
# day200_moving_average                       15705
# week52_high_low_change                       2368
# week52_high_low_change_perc                 14813
# week52_high                                  5764
# week52_high_change                           1698
# week52_high_change_perc                     10760
# ...

# %%
# which columns have unique values=1 , just show me the columns
df_mutual.nunique()[df_mutual.nunique()==1]
# Out:
# quote_type                  1
# region                      1
# currency                    1
# exchange_code               1
# exchange_name               1
# exchange_timezone           1
# fund_bonds_us_government    1
# dtype: int64

# %%
# drop columns quote_type ,region ,currency ,exchange_code ,exchange_name ,exchange_timezone ,fund_bonds_us_government                

df_mutual.drop(['quote_type','region','currency','exchange_code','exchange_name','exchange_timezone','fund_bonds_us_government'],axis=1,inplace=True)

# %%
df_mutual.isnull().sum().sort_values(ascending=False)
# Out:
# last_cap_gain                               23776
# fund_return_2021_q3                         23721
# fund_max_deferred_sales_load                20780
# fund_return_2021_q2                         20166
# fund_max_front_end_sales_load               20090
# fund_return_2000                            19827
# fund_return_2000_q4                         19827
# fund_return_2000_q3                         19734
# fund_return_2000_q2                         19599
# fund_return_2000_q1                         19462
# fund_return_2001                            19278
# fund_return_2001_q4                         19278
# fund_return_2001_q3                         19051
# fund_return_2001_q2                         18926
# fund_return_2001_q1                         18797
# fund_return_2002_q4                         18676
# fund_return_2002                            18673
# fund_return_2002_q3                         18509
# fund_return_2002_q2                         18322
# ...

# %%
# check for number of unique values in each column
df_mutual.nunique().sort_values(ascending=False)
# Out:
# fund_symbol                                 23783
# fund_return_2020_q1                         16876
# fund_return_2020                            16512
# fund_return_2019                            16146
# fund_return_2020_q2                         16040
# day50_moving_average                        15870
# day200_moving_average                       15705
# fund_return_2020_q4                         15359
# week52_high_low_change_perc                 14813
# fund_return_2017                            14722
# week52_low_change_perc                      13704
# fund_return_2018_q4                         13398
# fund_return_2018                            13164
# fund_return_2021_q1                         12787
# fund_return_2019_q1                         12681
# fund_return_2016                            12513
# fund_return_2013                            12312
# fund_return_2020_q3                         11144
# fund_return_2014                            10904
# ...

# %%
# check for duplicate in fund_symbol column
df_mutual.fund_symbol.duplicated().sum()
# Out:
# 0

# %%
# a data frame base on fund_category and fund_symbol, that total number of fund_symbol in each fund_category

df_mutual.groupby('fund_category')['fund_symbol'].nunique().sort_values(ascending=False)
# Out:
# fund_category
# Large Blend                             1235
# Large Growth                            1172
# Large Value                             1080
# Diversified Emerging Mkts                741
# Foreign Large Blend                      680
# Allocation--50% to 70% Equity            658
# High Yield Bond                          629
# Small Blend                              579
# Small Growth                             578
# Short-Term Bond                          570
# Intermediate Core-Plus Bond              566
# Mid-Cap Growth                           562
# Allocation--30% to 50% Equity            491
# World Allocation                         448
# Foreign Large Growth                     431
# Intermediate Core Bond                   413
# Small Value                              409
# Mid-Cap Value                            368
# Multisector Bond                         351
# Nontraditional Bond                      342
# ...

# %%
# a data frame base on fund_family and fund_symbol, that total number of fund_symbol in each fund_family

df_mutual.groupby('fund_family')['fund_symbol'].nunique().sort_values(ascending=False)
# Out:
# fund_family
# American Century Investments               1839
# Fidelity Investments                       1790
# Columbia Threadneedle                      1667
# American Funds                             1574
# BlackRock                                  1132
# Eaton Vance                                1076
# AllianceBernstein                           903
# BNY Mellon                                  784
# Invesco                                     652
# Delaware Funds by Macquarie                 598
# MFS                                         571
# Franklin Templeton Investments              446
# Dimensional Fund Advisors                   424
# Wells Fargo Funds                           412
# Virtus                                      356
# Calvert Research and Management             352
# American Beacon                             340
# Alger                                       296
# Calamos                                     232
# ...

# %%
# a data frame base on management_name and fund_symbol, that total number of fund_symbol in each management_name

df_mutual.groupby('management_name')['fund_symbol'].nunique().sort_values(ascending=False)
# Out:
# management_name
# Andrew F. Dierdorf              567
# Wesley K.-S. Phoa               320
# Jonathan W. Sage                264
# Scott A. Wilson                 260
# Jed S. Fogdall                  248
# Michelle J. Black               230
# Radu Gabudean                   184
# John Calamos                    160
# Jeffrey Houston                 156
# Anwiti Bahuguna                 132
# Adam A. Weigold                 132
# Terrance T. Hults               132
# Stephen J. Czepiel              128
# Robert Gahagan                  128
# Daniel J. Loewy                 108
# David A. Plecha                 108
# Vishal S. Khanduja              104
# Paul F. Fuchs                   104
# Joshua B. Kutin                 100
# Jon D. Adams                     80
# Lisa O'Connor                    80
# David Hoag                       78
# Michael J. Conn                  77
# Raghavendran Sivaraman           76
# Geoffrey D. Stein                73
# ...

# %%
# how many unique values in management_name column
df_mutual.management_name.nunique()
# Out:
# 1388

# %%
# Ranking of Mutual Funds just number  based on esg_score column

df_mutual.groupby('fund_symbol')['esg_score'].mean().sort_values(ascending=False). head(20)
# Out:
# fund_symbol
# RSNRX    41.21
# RSNYX    41.21
# RSNKX    41.21
# RGNCX    41.21
# GRHIX    40.97
# GRHAX    40.97
# OSPMX    40.05
# MLPRX    40.05
# SPNNX    40.05
# MLPDX    40.05
# MLPZX    40.05
# SPMQX    40.05
# SGDLX    39.67
# SGDIX    39.67
# HNRGX    38.98
# HNRIX    38.98
# CANIX    38.78
# OPGSX    38.17
# IOGYX    38.17
# OGMYX    38.17
# Name: esg_score, dtype: float64

# %%
# how many unique values in esg_score column
df_mutual.esg_score.nunique()
# Out:
# 1221

# %%
# define a new coloumn called esg_ranking based on esg_score column and sort values in descending order---method avg

df_mutual['esg_ranking']=df_mutual['esg_score'].rank(ascending=False)

# show me the output of esg_ranking column and esg_score column and fund_symbol column in descending order-- 
df_mutual[['esg_ranking','esg_score','fund_symbol']].sort_values(by='esg_ranking',ascending=True).head(30)
# Out:
#        esg_ranking  esg_score fund_symbol
# 19268          2.5      41.21       RSNRX
# 19269          2.5      41.21       RSNYX
# 19267          2.5      41.21       RSNKX
# 18772          2.5      41.21       RGNCX
# 8346           5.5      40.97       GRHIX
# 8345           5.5      40.97       GRHAX
# 16002          9.5      40.05       OSPMX
# 20446          9.5      40.05       SPMQX
# 20449          9.5      40.05       SPNNX
# 13905          9.5      40.05       MLPZX
# 13893          9.5      40.05       MLPDX
# 13902          9.5      40.05       MLPRX
# 20014         13.5      39.67       SGDLX
# 20013         13.5      39.67       SGDIX
# 9270          15.5      38.98       HNRIX
# 9269          15.5      38.98       HNRGX
# 2466          17.0      38.78       CANIX
# 10052         20.5      38.17       IOGYX
# 15955         20.5      38.17       OPGSX
# 15840         20.5      38.17       OGMNX
# 15839         20.5      38.17       OGMIX
# ...

# %%
# define a new coloumn called esg_ranking based on esg_score column and sort values in descending order---method min

df_mutual['esg_ranking']=df_mutual['esg_score'].rank(ascending=False, method='min')

# show me the output of esg_ranking column and esg_score column and fund_symbol column in descending order-- 
df_mutual[['esg_ranking','esg_score','fund_symbol']].sort_values(by='esg_ranking',ascending=True).head(30)
# Out:
#        esg_ranking  esg_score fund_symbol
# 19268          1.0      41.21       RSNRX
# 19269          1.0      41.21       RSNYX
# 19267          1.0      41.21       RSNKX
# 18772          1.0      41.21       RGNCX
# 8346           5.0      40.97       GRHIX
# 8345           5.0      40.97       GRHAX
# 16002          7.0      40.05       OSPMX
# 20446          7.0      40.05       SPMQX
# 20449          7.0      40.05       SPNNX
# 13905          7.0      40.05       MLPZX
# 13893          7.0      40.05       MLPDX
# 13902          7.0      40.05       MLPRX
# 20014         13.0      39.67       SGDLX
# 20013         13.0      39.67       SGDIX
# 9270          15.0      38.98       HNRIX
# 9269          15.0      38.98       HNRGX
# 2466          17.0      38.78       CANIX
# 10052         18.0      38.17       IOGYX
# 15955         18.0      38.17       OPGSX
# 15840         18.0      38.17       OGMNX
# 15839         18.0      38.17       OGMIX
# ...

# %%
# all columns names
df_mutual.columns
# Out:
# Index(['fund_symbol', 'fund_short_name', 'fund_long_name',
#        'initial_investment', 'subsequent_investment', 'fund_category',
#        'fund_family', 'management_name', 'management_bio',
#        'management_start_date',
#        ...
#        'peer_environment_max', 'social_score', 'peer_social_min',
#        'peer_social_avg', 'peer_social_max', 'governance_score',
#        'peer_governance_min', 'peer_governance_avg', 'peer_governance_max',
#        'esg_ranking'],
#       dtype='object', length=292)

# %%
# # Columns that are to be kept

# columns_to_keep = [
#                 '',
#                 '',
 
#  # Build dataframe including only the columns you want to keep
#     df_??? = df.loc[:,columns_to_keep]

# %%
# # columns to be kept : 
# fund_symbol
# fund_long_name
# initial_investment
# subsequent_investment
# fund_category
# fund_family
# management_name
# management_bio
# management_start_date
# total_net_assets
# year_to_date_return
# day50_moving_average
# day200_moving_average
# week52_high_low_change
# week52_high_low_change_perc
# investment_strategy
# fund_yield
# morningstar_overall_rating
# morningstar_risk_rating
# inception_date
# last_dividend
# annual_holdings_turnover
# investment_type
# size_type
# fund_annual_report_net_expense_ratio
# asset_cash
# asset_stocks
# asset_bonds
# asset_others
# asset_preferred
# asset_convertible
# fund_sector_basic_materials
# fund_sector_communication_services
# fund_sector_consumer_cyclical
# fund_sector_consumer_defensive
# fund_sector_energy
# fund_sector_financial_services
# fund_sector_healthcare
# fund_sector_industrials
# fund_sector_real_estate
# fund_sector_technology
# fund_sector_utilities
# morningstar_return_rating
# fund_return_ytd
# category_return_ytd
# fund_return_1month
# category_return_1month
# fund_return_3months
# category_return_3months
# fund_return_1year
# category_return_1year
# fund_return_3years
# category_return_3years
# fund_return_5years
# category_return_5years
# fund_return_10years
# category_return_10years
# fund_return_2020
# category_return_2020
# fund_return_2019
# category_return_2019
# fund_return_2018
# category_return_2018
# fund_return_2017
# category_return_2017
# fund_return_2016
# category_return_2016
# fund_return_2015
# category_return_2015
# fund_return_2014
# category_return_2014
# fund_return_2013
# category_return_2013
# fund_return_2012
# category_return_2012
# fund_return_2011
# category_return_2011
# fund_return_2010
# category_return_2010
# fund_return_2009
# category_return_2009
# fund_return_2008
# category_return_2008
# fund_return_2007
# category_return_2007
# fund_return_2006
# category_return_2006
# fund_return_2005
# category_return_2005
# fund_return_2004
# category_return_2004
# fund_return_2003
# category_return_2003
# fund_return_2002
# category_return_2002
# fund_return_2001
# category_return_2001
# fund_return_2000
# category_return_2000
# fund_alpha_3years
# fund_beta_3years
# fund_mean_annual_return_3years
# fund_r_squared_3years
# fund_stdev_3years
# fund_sharpe_ratio_3years
# fund_treynor_ratio_3years
# fund_alpha_5years
# fund_beta_5years
# fund_mean_annual_return_5years
# fund_r_squared_5years
# fund_stdev_5years
# fund_sharpe_ratio_5years
# fund_treynor_ratio_5years
# fund_alpha_10years
# fund_beta_10years
# fund_mean_annual_return_10years
# fund_r_squared_10years
# fund_stdev_10years
# fund_sharpe_ratio_10years
# fund_treynor_ratio_10years
# sustainability_score
# sustainability_rank
# esg_peer_group
# esg_peer_count
# esg_score
# peer_esg_min
# peer_esg_avg
# peer_esg_max
# environment_score
# peer_environment_min
# peer_environment_avg
# peer_environment_max
# social_score
# peer_social_min
# peer_social_avg
# peer_social_max
# governance_score
# peer_governance_min
# peer_governance_avg
# peer_governance_max

# define columns_to_keep list and keep only the columns you want to keep

columns_to_keep = [ 'fund_symbol', 'fund_long_name', 'initial_investment', 'subsequent_investment', 'fund_category', 'fund_family', 'management_name', 'management_bio', 'management_start_date', 'total_net_assets', 'year_to_date_return', 'day50_moving_average', 'day200_moving_average', 'week52_high_low_change', 'week52_high_low_change_perc', 'investment_strategy', 'fund_yield', 'morningstar_overall_rating', 'morningstar_risk_rating', 'inception_date', 'last_dividend', 'annual_holdings_turnover', 'investment_type', 'size_type', 'fund_annual_report_net_expense_ratio', 'asset_cash', 'asset_stocks', 'asset_bonds', 'asset_others', 'asset_preferred', 'asset_convertible', 'fund_sector_basic_materials', 'fund_sector_communication_services', 'fund_sector_consumer_cyclical', 'fund_sector_consumer_defensive', 'fund_sector_energy', 'fund_sector_financial_services', 'fund_sector_healthcare', 'fund_sector_industrials', 'fund_sector_real_estate', 'fund_sector_technology', 'fund_sector_utilities', 'morningstar_return_rating', 'fund_return_ytd', 'category_return_ytd', 'fund_return_1month', 'category_return_1month', 'fund_return_3months', 'category_return_3months', 'fund_return_1year', 'category_return_1year', 'fund_return_3years', 'category_return_3years', 'fund_return_5years', 'category_return_5years', 'fund_return_10years', 'category_return_10years', 'fund_return_2020', 'category_return_2020', 'fund_return_2019', 'category_return_2019', 'fund_return_2018', 'category_return_2018', 'fund_return_2017', 'category_return_2017', 'fund_return_2016', 'category_return_2016', 'fund_return_2015', 'category_return_2015', 'fund_return_2014', 'category_return_2014', 'fund_return_2013', 'category_return_2013', 'fund_return_2012', 'category_return_2012', 'fund_return_2011', 'category_return_2011', 'fund_return_2010', 'category_return_2010', 
'fund_return_2009', 'category_return_2009', 'fund_return_2008', 'category_return_2008', 'fund_return_2007', 'category_return_2007', 'fund_return_2006', 'category_return_2006', 'fund_return_2005', 'category_return_2005', 'fund_return_2004', 'category_return_2004', 'fund_return_2003', 'category_return_2003', 'fund_return_2002', 'category_return_2002', 'fund_return_2001', 'category_return_2001', 'fund_return_2000', 'category_return_2000', 'fund_alpha_3years', 'fund_beta_3years', 'fund_mean_annual_return_3years', 'fund_r_squared_3years', 'fund_stdev_3years', 'fund_sharpe_ratio_3years', 'fund_treynor_ratio_3years', 'fund_alpha_5years', 'fund_beta_5years', 'fund_mean_annual_return_5years', 'fund_r_squared_5years', 'fund_stdev_5years', 'fund_sharpe_ratio_5years', 'fund_treynor_ratio_5years', 'fund_alpha_10years', 'fund_beta_10years', 'fund_mean_annual_return_10years', 'fund_r_squared_10years', 'fund_stdev_10years', 'fund_sharpe_ratio_10years', 'fund_treynor_ratio_10years', 'sustainability_score', 'sustainability_rank', 'esg_peer_group', 'esg_peer_count', 'esg_score', 'peer_esg_min', 'peer_esg_avg', 'peer_esg_max', 'environment_score', 'peer_environment_min', 'peer_environment_avg', 'peer_environment_max', 'social_score', 'peer_social_min', 'peer_social_avg', 'peer_social_max', 'governance_score', 'peer_governance_min', 'peer_governance_avg', 'peer_governance_max']



# Build dataframe including only the columns you want to keep

df_mutual2= df_mutual.loc[:,columns_to_keep]

# %%
df_mutual2.shape
# Out:
# (23783, 140)

# %%
df_mutual2.head())
# Out:
#   fund_symbol                                     fund_long_name  \
# 0       AAAAX               DWS RREEF Real Assets Fund - Class A
# 1       AAAEX      Virtus AllianzGI Health Sciences Fund Class P
# 2       AAAFX  American Century One Choice Blend+ 2015 Portfo...
# 3       AAAGX             Thrivent Large Cap Growth Fund Class A
# 4       AAAHX  American Century One Choice Blend+ 2015 Portfo...
#
#    initial_investment  subsequent_investment     fund_category  \
# 0              1000.0                   50.0  World Allocation
# 1           1000000.0                    NaN            Health
# 2              2500.0                   50.0  Target-Date 2015
# 3              2000.0                   50.0      Large Growth
# 4           5000000.0                    NaN  Target-Date 2015
#
#                     fund_family   management_name  \
# 0                           DWS     John Vojticek
# 1                        Virtus  Christopher Chin
# ...
